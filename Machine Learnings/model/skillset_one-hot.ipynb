# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Vacancy Dataset

# %%
vacancy_data = pd.read_csv('data/job-list-all.csv')

# %%
user_data = pd.read_csv('data/user_data.csv')

# %%
user_data.head()
# Out:
#                                                                                                                                                                                                                                                                                                   User_ID  \
# 1  Yustaf Kusuma  "Yustaf Kusuma memiliki spesialisasi di Pyhton     Machine Learning                                   Front-end Engineering dengan pendidikan di Ins...  Data Engineer            AI Engineer. Saat ini berlokasi di Bandar Lamp...  "Pyhton                           Machine Learning
# 2  Siti Rahayu    "Siti Rahayu memiliki keahlian di UI/UX Design...  tertarik pada pekerjaan sebagai Front-end Deve...  UI/UX Designer. Saat ini berlokasi di Yogyakar...  "UI/UX Design            Full Stack Development"                            Universitas Gadjah Mada       "Front-end Developer
# ...
