# %% [markdown]
# # Collaborative Filtering

# %% [markdown]
# ### Import Model & Dependencies

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from transformers import BertTokenizer, TFBertModel
from sklearn.metrics.pairwise import cosine_similarity

# %%
#tokenizer = BertTokenizer.from_pretrained("indobenchmark/indobert-base-p1")
#model = TFBertModel.from_pretrained("indobenchmark/indobert-base-p1")

tokenizer = BertTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
model = TFBertModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
# Out:
# All model checkpoint layers were used when initializing TFBertModel.
#
# All the layers of TFBertModel were initialized from the model checkpoint at sentence-transformers/all-MiniLM-L6-v2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %% [markdown]
# ### Vacancy Dataset

# %%
vacancy_data = pd.read_csv('data/job_list_all.csv')

# %%
vacancy_data.head()

# %%
vacancy_data.shape

# %%
vacancy_data.info()

# %% [markdown]
# ### Select Features from the Vacancy Data

# %% [markdown]
# Selected Feature from Vacancy Data that will be used in the recommendation system:
# - Job Title
# - Skills Requiered

# %%
job_title = vacancy_data['Job_title']
skill_required = vacancy_data['Skills'].fillna('')

# %%
vacancy_data[['Job_title', 'Skills']]
# Out:
#                                Job_title  \
# 0                                Perawat
# 1                     Sales Sosial Media
# 2                       Fashion Designer
# 3        RPA Software Developer (UIPATH)
# 4                         SEO Specialist
# ...                                  ...
# 2965                     Sales Executive
# 2966                             Drafter
# 2967                         3D Animator
# 2968                         Crew Outlet
# 2969  Senior Transfer Pricing Consultant
#
#                                                  Skills
# 0     Dapat Berkomunikasi Secara Baik, Berorientasi ...
# 1                                                   NaN
# 2     Trend Forecasting, Pattern Making, Fashion Sty...
# 3                                                   NaN
# 4     Search Engine Optimization (SEO), Seo/sem, SEO...
# ...                                                 ...
# 2965                                                NaN
# 2966  2D & 3D Drafter, Construction, Arsitek & Draft...
# 2967  Character Animation, Target Oriented, 3D Animator
# 2968  Jujur, teliti, dan rajin, Bekerja Sama Secara ...
# 2969  Transfer Pricing Tax, International Tax, Trans...
#
# [2970 rows x 2 columns]

# %% [markdown]
# ### Generate Embedding Vector from Vacancy Data Features

# %% [markdown]
# Job Title

# %%
job_title_embedding = tokenizer(list(job_title), padding=True, truncation=True, return_tensors="tf")

job_title_output = model(**job_title_embedding)
job_title_embedding = tf.reduce_mean(job_title_output.last_hidden_state, axis=1)

print(job_title_embedding)
# Out:
# tf.Tensor(
# [[ 0.09893861  0.6709868  -0.05763523 ... -0.09025701 -0.05610005
#    0.09990735]
#  [ 0.06790408  0.29846144 -0.03877079 ... -0.05968623 -0.20636159
#    0.39817366]
#  [-0.18341003  0.81219375  0.13489076 ... -0.6137716  -0.19563222
#    0.21891122]
#  ...
#  [-0.33673918  0.46139348  0.12747812 ... -0.16478837 -0.06735568
#    0.23283784]
#  [ 0.10142635  0.6584376   0.13544369 ...  0.1945655   0.37138313
#    0.26483524]
#  [-0.02047656  0.60060596 -0.08322085 ... -0.25413296  0.06816447
#    0.35279298]], shape=(2970, 384), dtype=float32)

# %% [markdown]
# Skills Required

# %%
batch_size = 8  # Adjust the batch size based on your available memory
num_batches = int(np.ceil(len(skill_required) / batch_size))

# Initialize an empty list to store the embeddings
all_embeddings = []

# Process the skills in batches
for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = min((i + 1) * batch_size, len(skill_required))
    
    # Get the current batch of skills
    current_batch = skill_required[start_idx:end_idx]

    # Tokenize and get embeddings for the current batch
    skills_required_embedding = tokenizer(list(current_batch), padding=True, truncation=True, return_tensors="tf")
    skills_required_output = model(**skills_required_embedding)
    skills_required_embedding_batch = tf.reduce_mean(skills_required_output.last_hidden_state, axis=1)

    # Append the batch embeddings to the list
    all_embeddings.append(skills_required_embedding_batch)

# Concatenate the embeddings from all batches
skills_required_embedding = tf.concat(all_embeddings, axis=0)

print(skills_required_embedding)
# Out:
# tf.Tensor(
# [[-0.04734316 -0.04068359 -0.05341089 ... -0.0326941   0.12434901
#    0.08022784]
#  [-0.14200833  0.06820566  0.30239564 ...  0.05579124  0.03658259
#   -0.19898558]
#  [-0.36620596 -0.27244887  0.29949224 ... -0.3608912  -0.32922253
#    0.33754823]
#  ...
#  [-0.41038263 -0.00828709  0.04550349 ... -0.10936541  0.06763899
#    0.09309419]
#  [-0.34337884  0.11199798 -0.09946654 ...  0.00533551 -0.30713984
#    0.09499694]
#  [-0.14812972 -0.07734243  0.12420789 ... -0.21625116  0.47002015
#    0.10632435]], shape=(2970, 384), dtype=float32)

# %% [markdown]
# Combine embeddings vector from job_title and skills_required

# %%
''' 
vacancy_data_embedding = tf.concat([job_title_embedding, skills_required_embedding], axis=1)
print(vacancy_data_embedding)
'''

vacancy_data_embedding = job_title_embedding + skills_required_embedding
print(vacancy_data_embedding)
# Out:
# tf.Tensor(
# [[ 5.15954420e-02  6.30303204e-01 -1.11046121e-01 ... -1.22951105e-01
#    6.82489574e-02  1.80135190e-01]
#  [-7.41042495e-02  3.66667092e-01  2.63624847e-01 ... -3.89498845e-03
#   -1.69779003e-01  1.99188083e-01]
#  [-5.49615979e-01  5.39744854e-01  4.34383005e-01 ... -9.74662781e-01
#   -5.24854779e-01  5.56459427e-01]
#  ...
#  [-7.47121811e-01  4.53106403e-01  1.72981620e-01 ... -2.74153769e-01
#    2.83300877e-04  3.25932026e-01]
#  [-2.41952494e-01  7.70435572e-01  3.59771475e-02 ...  1.99901015e-01
#    6.42432868e-02  3.59832168e-01]
#  [-1.68606281e-01  5.23263514e-01  4.09870371e-02 ... -4.70384121e-01
#    5.38184643e-01  4.59117323e-01]], shape=(2970, 384), dtype=float32)

# %% [markdown]
# ### User Dataset

# %%
user_data = pd.read_csv('data/user_data.csv')

# %%
user_data.head()

# %%
user_data.shape

# %%
user_data.info()

# %% [markdown]
# ### Select Features from the User Data

# %% [markdown]
# Selected Feature from User Data that will be used in the recommendation system:
# - Summary
# - Specialities
# - Preference

# %%
'''
summary = user_data['Summary'].fillna('')
specialities = user_data['Specialities'].fillna('')
preference = user_data['Preference'].fillna('')
'''
user_data_pivot = user_data.loc[0, ['Specialities', 'Preference']].fillna('')
user_data_text = ' '.join(user_data_pivot)
print(user_data_text)
# Out:
# Pyhton, Machine Learning, Front-end Engineering Machine Learning Engineer, Data Engineer, AI Engineer

# %%
# user_data[['Summary', 'Specialities', 'Preference']].head()

# %% [markdown]
# ### Generate Embedding Vector from User Data Features

# %% [markdown]
# Summary

# %%
summary_embedding = tokenizer(list(summary), padding=True, truncation=True, return_tensors="tf")

summary_output = model(**summary_embedding)
summary_embedding = tf.reduce_mean(summary_output.last_hidden_state, axis=1)

print(summary_embedding)

# %% [markdown]
# Specialities

# %%
specialities_embedding = tokenizer(list(specialities), padding=True, truncation=True, return_tensors="tf")

specialities_output = model(**specialities_embedding)
specialities_embedding = tf.reduce_mean(specialities_output.last_hidden_state, axis=1)

print(specialities_embedding)
# Out:
# tf.Tensor(
# [[-0.7591557  -0.2853693  -0.04422127 ...  0.22754283  0.51835626
#    0.30709255]
#  [-0.37234053 -0.16718821  0.20641777 ...  0.2686259   0.04418864
#    0.32030675]
#  [-0.03494948  0.03984269 -0.00202686 ... -0.06028648 -0.05858291
#    0.3398166 ]
#  ...
#  [ 0.08599003  0.43470374  0.01070081 ... -0.37930927  0.21111889
#    0.43160692]
#  [-0.23071201  0.15263826 -0.1491357  ...  0.2772762   0.0031032
#    0.2470112 ]
#  [-0.37705415 -0.2945982   0.18425955 ...  0.1156285   0.3197995
#    0.20341104]], shape=(40, 384), dtype=float32)

# %% [markdown]
# Preference

# %%
preference_embedding = tokenizer(list(preference), padding=True, truncation=True, return_tensors="tf")

preference_output = model(**preference_embedding)
preference_embedding = tf.reduce_mean(preference_output.last_hidden_state, axis=1)

print(preference_embedding)
# Out:
# tf.Tensor(
# [[-0.27622938 -0.5186211   0.28838944 ... -0.23163259  0.15096131
#    0.10167424]
#  [-0.23453705 -0.12980202 -0.15797941 ...  0.23230988  0.34744868
#    0.4337092 ]
#  [-0.11287393  0.06269799  0.02106555 ... -0.31289685 -0.20406961
#    0.11203896]
#  ...
#  [ 0.03132712  0.31291494  0.09176126 ... -0.7587497  -0.00762711
#    0.6370269 ]
#  [-0.23912387 -0.18840477  0.23998892 ... -0.15042606  0.03189412
#    0.29902086]
#  [-0.41676292 -0.11168133 -0.09661361 ... -0.08892183  0.5930506
#    0.02420565]], shape=(40, 384), dtype=float32)

# %% [markdown]
# Combine Embedding Vector from User Data

# %% [markdown]
# ### Searching Similarity
# I'm using cosine similarity to searching the similarity between both vectorized embedding text

# %%
''' 
# Reshape cf_embedding menjadi matrix 2 dimensi
cf_embedding_np = cf_embedding.numpy().reshape(1, -1)
'''

# %%
similarities = cosine_similarity(vacancy_data_embedding, user_data_embedding)

# %%
top_10_indices = np.argsort(similarities, axis=1)[:, -10:]

# %%
for i, job_index in enumerate(top_10_indices[0]):
    similarity_score = similarities[0, job_index]
    job_title = vacancy_data.iloc[job_index]
    print(f"Similarity {i + 1}: {similarity_score}, Job Title: {job_title}")
# Out:
# Similarity 1: 0.17065221071243286, Job Title: Company                                           Yanoshi Omiyage
# Job_title                                      Sales Sosial Media
# Location            Bekasi Selatan, Bekasi, Jawa Barat, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Mengelola aktifitas penjualan di platform medi...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 1, dtype: object
# Similarity 2: 0.19600795209407806, Job Title: Company                                         MII CMT Indonesia
# Job_title                                        Fashion Designer
# Location                   Karawaci, Tangerang, Banten, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills          Trend Forecasting, Pattern Making, Fashion Sty...
# Descriptions    Memiliki pengalaman sebagai Fashion Designer p...
# Links           https://glints.com/id/opportunities/jobs/fashi...
# Name: 2, dtype: object
# Similarity 3: 0.19600795209407806, Job Title: Company                                             Noble Academy
# Job_title                                        Staff Pendidikan
# Location        Grogol Petamburan, Jakarta Barat, DKI Jakarta,...
# Salary                                                Rp5jt-Rp7jt
# Work Type                                             Penuh Waktu
# Skills          Lancar Berbahasa Inggris, Computer And Network...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/staff...
# Name: 60, dtype: object
# Similarity 4: 0.20180445909500122, Job Title: Company                                   PT Wahyuni Jaya Mandiri
# Job_title                                             Cook Helper
# Location        Kebayoran Baru, Jakarta Selatan, DKI Jakarta, ...
# Salary                                                    Rp1,5jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/cook-...
# Name: 51, dtype: object
# Similarity 5: 0.20180445909500122, Job Title: Company                                          DC BEAUTY CENTRE
# Job_title                                       Eyelash Therapist
# Location        Setiabudi, Jakarta Selatan, DKI Jakarta, Indon...
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Gaji pokok, Komisi (Therapist), Uang makan, Bo...
# Links           https://glints.com/id/opportunities/jobs/eyela...
# Name: 16, dtype: object
# Similarity 6: 0.20180445909500122, Job Title: Company                                 PT. Rumah Kumbang Berdaya
# Job_title                      Sarana dan prasarana ( Freelance )
# Location               Mulyorejo, Surabaya, Jawa Timur, Indonesia
# Salary                                            Rp100rb-Rp100rb
# Work Type                                                  Harian
# Skills          Team Work, Strong Leadership Skills, Strong wo...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/saran...
# Name: 17, dtype: object
# Similarity 7: 0.20180445909500122, Job Title: Company                                          KIAN Health Corp
# Job_title                             Business Development Intern
# Location              Medan Satria, Bekasi, Jawa Barat, Indonesia
# Salary                                              Rp500rb-Rp1jt
# Work Type                                                  Magang
# Skills                                                        NaN
# Descriptions    Market Research: Conduct market research to id...
# Links           https://glints.com/id/opportunities/jobs/busin...
# Name: 29, dtype: object
# Similarity 8: 0.20409245789051056, Job Title: Company                                              Ivory Studio
# Job_title                                Sales Penjualan (Online)
# Location        Kapanewon Depok, Kab. Sleman, DI Yogyakarta, I...
# Salary                                              Rp2,2jt-Rp5jt
# Work Type                                             Penuh Waktu
# Skills          Mengetik Dengan Cepat, Berkomunikasi Dengan Ba...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 21, dtype: object
# Similarity 9: 0.21019336581230164, Job Title: Company                                     Cv Cabin Nuansa Indah
# Job_title                                         Content Creator
# Location        Cengkareng, Jakarta Barat, DKI Jakarta, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Diutamakan  berumur dibawah 28 tahun., bisa be...
# Links           https://glints.com/id/opportunities/jobs/conte...
# Name: 30, dtype: object
# Similarity 10: 0.21019336581230164, Job Title: Company                                      PT Natas Nitis Netes
# Job_title                                   Accounting Supervisor
# Location            Bekasi Selatan, Bekasi, Jawa Barat, Indonesia
# Salary                                              Rp5,5jt-Rp7jt
# Work Type                                                 Kontrak
# Skills                                                        NaN
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/accou...
# Name: 39, dtype: object
# Similarity 11: 0.21019336581230164, Job Title: Company                            PT Optima Technology Indonesia
# Job_title                                    Ecommerce Specialist
# Location        Penjaringan, Jakarta Utara, DKI Jakarta, Indon...
# Salary                                                Rp5jt-Rp8jt
# Work Type                                             Penuh Waktu
# Skills          Ecommerce, Social Media Admin, Ecommerce Platf...
# Descriptions    WAJIB MENGERTI SEMUA APP SHOP DARI DASAR SAMPA...
# Links           https://glints.com/id/opportunities/jobs/ecomm...
# Name: 52, dtype: object
# Similarity 12: 0.211573988199234, Job Title: Company                                      Artiz Studio Jakarta
# Job_title                                     Marketing Executive
# Location           Tebet, Jakarta Selatan, DKI Jakarta, Indonesia
# Salary                                               Rp7jt-Rp15jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Mengembangkan rencana merek dan strategi pemas...
# Links           https://glints.com/id/opportunities/jobs/marke...
# Name: 42, dtype: object
# Similarity 13: 0.21310032904148102, Job Title: Company                                     PT Dream Forest Media
# Job_title                                            ADMIN TIKTOK
# Location        Penjaringan, Jakarta Utara, DKI Jakarta, Indon...
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills          Social Media Marketing, Digital Marketing, Soc...
# Descriptions    Merekrut host yang sering melakukan live strea...
# Links           https://glints.com/id/opportunities/jobs/admin...
# Name: 22, dtype: object
# Similarity 14: 0.21381008625030518, Job Title: Company                                           MITRAPABRIK.COM
# Job_title                                           Sales Project
# Location                  Wiyung, Surabaya, Jawa Timur, Indonesia
# Salary                                              Rp3jt-Rp3,5jt
# Work Type                                             Penuh Waktu
# Skills          Komputer Ms Office, Memiliki Kemampuan Komunik...
# Descriptions    Mengidentifikasi dan menghubungi prospek poten...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 23, dtype: object
# Similarity 15: 0.2329772561788559, Job Title: Company                                               Algoritmics
# Job_title                                   Online Python Teacher
# Location        Cempaka Putih, Jakarta Pusat, DKI Jakarta, Ind...
# Salary                                            Rp4,5jt-Rp9,5jt
# Work Type                                             Paruh Waktu
# Skills                                                        NaN
# Descriptions    100% remote job., Teach Coding to the Indonesi...
# Links           https://glints.com/id/opportunities/jobs/onlin...
# Name: 68, dtype: object
# Similarity 16: 0.2329772561788559, Job Title: Company                                Sumberdaya Andalan Mandiri
# Job_title                               Sales Generalis Bank BUMN
# Location        Kebayoran Baru, Jakarta Selatan, DKI Jakarta, ...
# Salary                                              Rp4,5jt-Rp5jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Pria/Wanita, Usia Maksimal 33 tahun, Pendidika...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 10, dtype: object
# Similarity 17: 0.23519983887672424, Job Title: Company                         Digniti Aku Nusantara (DignityKu)
# Job_title                                            Sales Person
# Location        Pasar Minggu, Jakarta Selatan, DKI Jakarta, In...
# Salary                                                    Rp2,5jt
# Work Type                                                 Kontrak
# Skills                                                        NaN
# Descriptions    Mengidentifikasi dan menghubungi prospek poten...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 45, dtype: object
# Similarity 18: 0.23519983887672424, Job Title: Company                                PT. Parama Sutera Autotren
# Job_title                                  Accounting & Tax Staff
# Location                     Pinang, Tangerang, Banten, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills                Tax Accounting, E-spt (tax), Administration
# Descriptions    Usia maksimal 30 tahun, Minimal S1 jurusan aku...
# Links           https://glints.com/id/opportunities/jobs/accou...
# Name: 25, dtype: object
# Similarity 19: 0.23519983887672424, Job Title: Company                                       Trans Entertainment
# Job_title                                    BRANCH MANAGER TEGAL
# Location             Tegal Selatan, Tegal, Jawa Tengah, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills                         Leadership, Sales, Sales Marketing
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/branc...
# Name: 47, dtype: object
# Similarity 20: 0.23519983887672424, Job Title: Company                                      Ikonsultan Inovatama
# Job_title                                  Java Software Engineer
# Location        Tanah Abang, Jakarta Pusat, DKI Jakarta, Indon...
# Salary                                              Rp10jt-Rp25jt
# Work Type                                                 Kontrak
# Skills          Apache Kafka, Eureka, Spring Framework, Kubern...
# Descriptions    Proficiency in Java programming., Strong knowl...
# Links           https://glints.com/id/opportunities/jobs/java-...
# Name: 6, dtype: object
# Similarity 21: 0.23519983887672424, Job Title: Company                           PT MANDIRI UTAMA FINANCE BLITAR
# Job_title                                         Kolektor Blitar
# Location               Sanan Wetan, Blitar, Jawa Timur, Indonesia
# Salary                                            Rp2,3jt-Rp2,3jt
# Work Type                                             Penuh Waktu
# Skills          Berani, Rajin Dan Ulet, Mampu Bekerja Keras Da...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/kolek...
# Name: 64, dtype: object
# Similarity 22: 0.24007846415042877, Job Title: Company                             PT. Eversaas Power Technology
# Job_title                                Presales System Engineer
# Location        Kebon Jeruk, Jakarta Barat, DKI Jakarta, Indon...
# Salary                                               Rp6jt-Rp10jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Pria Usia min. 25 tahun, Pendidikan min. D3 / ...
# Links           https://glints.com/id/opportunities/jobs/presa...
# Name: 11, dtype: object
# Similarity 23: 0.24007846415042877, Job Title: Company                                PT Val Konsultan Indonesia
# Job_title                                        Sales Consultant
# Location         Medan Selayang, Medan, Sumatera Utara, Indonesia
# Salary                                              Rp3jt-Rp3,8jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Initiate and lead human resource programs and ...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 40, dtype: object
# Similarity 24: 0.24007846415042877, Job Title: Company                                               Algoritmics
# Job_title                                     Trial Class Manager
# Location        Taman Sari, Jakarta Barat, DKI Jakarta, Indonesia
# Salary                                              Rp3,6jt-Rp7jt
# Work Type                                             Paruh Waktu
# Skills                                Telesales, B2C Sales, Sales
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/trial...
# Name: 69, dtype: object
# Similarity 25: 0.24007846415042877, Job Title: Company                                   PT. Carissa Mega Pesona
# Job_title                                     Brand Promotor Bali
# Location                Denpasar Barat, Denpasar, Bali, Indonesia
# Salary                                            Rp1,2jt-Rp1,2jt
# Work Type                                                 Kontrak
# Skills          Teamwork, Memiliki Kemampuan Komunikasi Yang B...
# Descriptions    Melakukan Aktifitas Promosi di Area Penempatan...
# Links           https://glints.com/id/opportunities/jobs/brand...
# Name: 34, dtype: object
# Similarity 26: 0.24007846415042877, Job Title: Company                                    Kreativ Lift Indonesia
# Job_title                                       Account Executive
# Location        Kelapa Gading, Jakarta Utara, DKI Jakarta, Ind...
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills          Negotiation Skill, Sales Management, Sales Mar...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/accou...
# Name: 44, dtype: object
# Similarity 27: 0.24293330311775208, Job Title: Company                                 PT Sejahtera Mitra Solusi
# Job_title                Sales Officer - Jawa Tengah & Yogyakarta
# Location        Ungaran Barat, Kab. Semarang, Jawa Tengah, Ind...
# Salary                                              Rp2,5jt-Rp5jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Melaksanakan sales survei kelayakan konsumen g...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 58, dtype: object
# Similarity 28: 0.24293330311775208, Job Title: Company                                          Braja Biru Abadi
# Job_title                                                 Perawat
# Location           Menteng, Jakarta Pusat, DKI Jakarta, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills          Dapat Berkomunikasi Secara Baik, Berorientasi ...
# Descriptions    Wanita, usia min. 23 tahun, Pendidikan D3 Kepe...
# Links           https://glints.com/id/opportunities/jobs/peraw...
# Name: 0, dtype: object
# Similarity 29: 0.24293330311775208, Job Title: Company                                 PT Sejahtera Mitra Solusi
# Job_title                Sales Officer - Jawa Tengah & Yogyakarta
# Location          Ungaran Barat, Semarang, Jawa Tengah, Indonesia
# Salary                                              Rp2,5jt-Rp5jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Melaksanakan sales survei kelayakan konsumen g...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 61, dtype: object
# Similarity 30: 0.24293330311775208, Job Title: Company                                         PT TANAH AIR RAYA
# Job_title                                       Community Manager
# Location         Pabean Cantikan, Surabaya, Jawa Timur, Indonesia
# Salary                                              Rp4jt-Rp5,7jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/commu...
# Name: 15, dtype: object
# Similarity 31: 0.24293330311775208, Job Title: Company                                Indonesia Global Solusindo
# Job_title                         RPA Software Developer (UIPATH)
# Location        Grogol Petamburan, Jakarta Barat, DKI Jakarta,...
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/rpa-s...
# Name: 3, dtype: object
# Similarity 32: 0.24486935138702393, Job Title: Company                                ID Beauty Clinic Indonesia
# Job_title                                              Accounting
# Location           Menteng, Jakarta Pusat, DKI Jakarta, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills          Accounting, Berkomunikasi Dengan Baik, Mampu b...
# Descriptions    Wajib berpengalaman, Wanita/pria, Pengalaman m...
# Links           https://glints.com/id/opportunities/jobs/accou...
# Name: 31, dtype: object
# Similarity 33: 0.24486935138702393, Job Title: Company                             PT The Lorry Online Indonesia
# Job_title                                     Operation Executive
# Location                 Rungkut, Surabaya, Jawa Timur, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/opera...
# Name: 53, dtype: object
# Similarity 34: 0.2526153326034546, Job Title: Company                                       The Everest Project
# Job_title                                          CS Online Shop
# Location        Kemantren Umbulharjo, Yogyakarta, DI Yogyakart...
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/cs-on...
# Name: 33, dtype: object
# Similarity 35: 0.2526153326034546, Job Title: Company                                   PT Wahyuni Jaya Mandiri
# Job_title                                            Head Kitchen
# Location        Kebayoran Baru, Jakarta Selatan, DKI Jakarta, ...
# Salary                                              Rp2jt-Rp2,5jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/head-...
# Name: 54, dtype: object
# Similarity 36: 0.2526153326034546, Job Title: Company                                 PT PINK SERVICE INDONESIA
# Job_title                                                   SALES
# Location             Batam Kota, Batam, Kepulauan Riau, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills          Target Oriented, Customer Relations, Market St...
# Descriptions    Usia Maksimal 40 thn, Pendidikan min D3/S1 seg...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 28, dtype: object
# Similarity 37: 0.2526153326034546, Job Title: Company                                    Kreativ Lift Indonesia
# Job_title                             Sales Expert for Home Lifts
# Location        Kelapa Gading, Jakarta Utara, DKI Jakarta, Ind...
# Salary                                              Rp5jt-Rp7,5jt
# Work Type                                             Penuh Waktu
# Skills          Social Media Marketing, Digital Marketing, Eng...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 43, dtype: object
# Similarity 38: 0.2526153326034546, Job Title: Company                                               Algoritmics
# Job_title                                       B2C Sales Manager
# Location        Taman Sari, Jakarta Barat, DKI Jakarta, Indonesia
# Salary                                              Rp3,6jt-Rp7jt
# Work Type                                             Paruh Waktu
# Skills                                Telesales, B2C Sales, Sales
# Descriptions    Anda bertanggung jawab untuk mempresentasikan ...
# Links           https://glints.com/id/opportunities/jobs/b2c-s...
# Name: 65, dtype: object
# Similarity 39: 0.2526153326034546, Job Title: Company                                   PT Istana Surya Perkasa
# Job_title                                         Sales Executive
# Location                 Sawahan, Surabaya, Jawa Timur, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills               Sales and Marketing, B2b Sales, Retail Sales
# Descriptions    Laki- Laki, maksimal 38 tahun, Pendidikan mini...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 7, dtype: object
# Similarity 40: 0.2526153326034546, Job Title: Company                                     PT VELLIA KANDI UTAMA
# Job_title                                       Dokter kecantikan
# Location            Serpong, Tangerang Selatan, Banten, Indonesia
# Salary                                               Rp6jt-Rp15jt
# Work Type                                             Penuh Waktu
# Skills          Marketing, Perawatan Kecantikan, paham dengan ...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/dokte...
# Name: 48, dtype: object
# Similarity 41: 0.2526153326034546, Job Title: Company                                  PT. Surya Lintas Pasifik
# Job_title             Inventory Control and Warehouse Coordinator
# Location                 Bubutan, Surabaya, Jawa Timur, Indonesia
# Salary                                              Rp4jt-Rp5,5jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/inven...
# Name: 50, dtype: object
# Similarity 42: 0.2526153326034546, Job Title: Company                                               Algoritmics
# Job_title                                     Trial Class Manager
# Location        Pasar Minggu, Jakarta Selatan, DKI Jakarta, In...
# Salary                                              Rp3,6jt-Rp7jt
# Work Type                                             Paruh Waktu
# Skills                                Telesales, B2C Sales, Sales
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/trial...
# Name: 70, dtype: object
# Similarity 43: 0.2526153326034546, Job Title: Company                                  Sumber Nelayan Indonesia
# Job_title                    SALES CANVAS MOTORIS WILAYAH JAKARTA
# Location        Cengkareng, Jakarta Barat, DKI Jakarta, Indonesia
# Salary                                              Rp2jt-Rp2,3jt
# Work Type                                             Penuh Waktu
# Skills          Memiliki Kemampuan Komunikasi Yang Baik, Sales...
# Descriptions    Waktu Jam Kerja Menyesuaikan Buka Tutup Pasar ...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 26, dtype: object
# Similarity 44: 0.25300154089927673, Job Title: Company                                  PT. Java Vapor Indonesia
# Job_title                                        Supervisor Store
# Location                Sukolilo, Surabaya, Jawa Timur, Indonesia
# Salary                                              Rp4,5jt-Rp6jt
# Work Type                                             Penuh Waktu
# Skills             Store Management, Sales Supervisor, Leadership
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/super...
# Name: 35, dtype: object
# Similarity 45: 0.25300154089927673, Job Title: Company                                    Kreativ Lift Indonesia
# Job_title                                   Admin Project Manager
# Location        Kelapa Gading, Jakarta Utara, DKI Jakarta, Ind...
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills          Construction, Construction engineering, Constr...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/admin...
# Name: 41, dtype: object
# Similarity 46: 0.25300154089927673, Job Title: Company                                    PT Delta Tekno Perkasa
# Job_title                                    SPV Cleaning Service
# Location        Kebon Jeruk, Jakarta Barat, DKI Jakarta, Indon...
# Salary                                                Rp3jt-Rp4jt
# Work Type                                                 Kontrak
# Skills          Leadership Skills, Service Oriented, Teamwork ...
# Descriptions    Usia 28 – 35 tahun, Pendidikan Minimal SMA/SMK...
# Links           https://glints.com/id/opportunities/jobs/spv-c...
# Name: 20, dtype: object
# Similarity 47: 0.25472235679626465, Job Title: Company                                              Kebab Bosman
# Job_title                                      Marketing Domestic
# Location                Wonocolo, Surabaya, Jawa Timur, Indonesia
# Salary                                                      Rp4jt
# Work Type                                             Penuh Waktu
# Skills          Marketing Communications, Management EMKL, emk...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/marke...
# Name: 38, dtype: object
# Similarity 48: 0.25472235679626465, Job Title: Company                                               Algoritmics
# Job_title                                     Trial Class Manager
# Location            Cakung, Jakarta Timur, DKI Jakarta, Indonesia
# Salary                                              Rp3,6jt-Rp7jt
# Work Type                                             Paruh Waktu
# Skills                                Telesales, B2C Sales, Sales
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/trial...
# Name: 71, dtype: object
# Similarity 49: 0.25472235679626465, Job Title: Company                                       PT Redpod Indonesia
# Job_title                                Marketing Communications
# Location        Tanjung Priok, Jakarta Utara, DKI Jakarta, Ind...
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Candidate must possess at least Diploma, Bache...
# Links           https://glints.com/id/opportunities/jobs/marke...
# Name: 55, dtype: object
# Similarity 50: 0.26318347454071045, Job Title: Company                                              Kebab Bosman
# Job_title                                          Marketing Exim
# Location                Wonocolo, Surabaya, Jawa Timur, Indonesia
# Salary                                                      Rp4jt
# Work Type                                             Penuh Waktu
# Skills            Exim, Good Communication Skills, Eksport-Import
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/marke...
# Name: 37, dtype: object
# Similarity 51: 0.26318347454071045, Job Title: Company                                         PT TANAH AIR RAYA
# Job_title                                  Staff Customer Service
# Location         Pabean Cantikan, Surabaya, Jawa Timur, Indonesia
# Salary                                            Rp3,5jt-Rp5,3jt
# Work Type                                             Penuh Waktu
# Skills          Analisa Proses Bisnis, Public Speaking, Micros...
# Descriptions    Menangani pertanyaan pelanggan melalui telepon...
# Links           https://glints.com/id/opportunities/jobs/staff...
# Name: 14, dtype: object
# Similarity 52: 0.268841028213501, Job Title: Company                                   PT Pintar Pemenang Asia
# Job_title                        Enrollment Counselor - Surakarta
# Location               Laweyan, Surakarta, Jawa Tengah, Indonesia
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                                 Kontrak
# Skills                                                        NaN
# Descriptions    Bekerja dengan calon siswa dalam proses seleks...
# Links           https://glints.com/id/opportunities/jobs/enrol...
# Name: 56, dtype: object
# Similarity 53: 0.268841028213501, Job Title: Company                                          Sasmita Property
# Job_title                                Sales Executive Property
# Location                Bogor Barat, Bogor, Jawa Barat, Indonesia
# Salary                                              Rp3jt-Rp4,5jt
# Work Type                                                 Kontrak
# Skills          Marketing Promotion, Customer Service, Marketi...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 12, dtype: object
# Similarity 54: 0.27183008193969727, Job Title: Company                                  PT. Java Vapor Indonesia
# Job_title                                             Manager RnD
# Location                Sukolilo, Surabaya, Jawa Timur, Indonesia
# Salary                                               Rp8jt-Rp12jt
# Work Type                                             Penuh Waktu
# Skills               Problem Solving, Team Leadership, Leadership
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/manag...
# Name: 32, dtype: object
# Similarity 55: 0.4688253402709961, Job Title: Company                                  PT. Java Vapor Indonesia
# Job_title                                                Staff IT
# Location                Sukolilo, Surabaya, Jawa Timur, Indonesia
# Salary                                                Rp4jt-Rp6jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/staff...
# Name: 36, dtype: object
# Similarity 56: 0.4688253402709961, Job Title: Company                                    Trans Studio Mall Bali
# Job_title                                  Staff Customer Service
# Location                Denpasar Barat, Denpasar, Bali, Indonesia
# Salary                                                Rp3jt-Rp3jt
# Work Type                                                 Kontrak
# Skills                                                        NaN
# Descriptions    Menangani pertanyaan pelanggan melalui telepon...
# Links           https://glints.com/id/opportunities/jobs/staff...
# Name: 46, dtype: object
# Similarity 57: 0.4688253402709961, Job Title: Company                 BILLION ASCENT VIETNAM INDUSTRIAL LIMITED
# Job_title                             Đại Diện Bán Hàng Quảng Cáo
# Location        Kebon Jeruk, Jakarta Barat, DKI Jakarta, Indon...
# Salary                          Perusahaan tidak menampilkan gaji
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/dai-d...
# Name: 63, dtype: object
# Similarity 58: 0.4688253402709961, Job Title: Company                                          DC BEAUTY CENTRE
# Job_title                                          Nail Therapist
# Location        Setiabudi, Jakarta Selatan, DKI Jakarta, Indon...
# Salary                                            Rp2,5jt-Rp2,5jt
# Work Type                                             Penuh Waktu
# Skills                                                        NaN
# Descriptions    Gaji pokok, Komisi (Therapist), Uang makan, Bo...
# Links           https://glints.com/id/opportunities/jobs/nail-...
# Name: 18, dtype: object
# Similarity 59: 0.4688253402709961, Job Title: Company                                    Klinik Utama Skinnaire
# Job_title              Front Liner Klinik Utama (Kulit & Kelamin)
# Location            Sumur Bandung, Bandung, Jawa Barat, Indonesia
# Salary                                              Rp3jt-Rp4,2jt
# Work Type                                             Penuh Waktu
# Skills          Problem Solving And Time Management, Memiliki ...
# Descriptions    Melayani kepentingan pasien sesuai dengan pros...
# Links           https://glints.com/id/opportunities/jobs/front...
# Name: 13, dtype: object
# Similarity 60: 0.4688253402709961, Job Title: Company                                     Financia Golden Trade
# Job_title                                     Staff Telemarketing
# Location        Grogol Petamburan, Jakarta Barat, DKI Jakarta,...
# Salary                                             Rp2,5jt-Rp10jt
# Work Type                                                 Kontrak
# Skills          Komputer Ms Office, Customer Relationship Mana...
# Descriptions    Memperkenalkan produk dan kelebihannya secara ...
# Links           https://glints.com/id/opportunities/jobs/staff...
# Name: 5, dtype: object
# Similarity 61: 0.4688253402709961, Job Title: Company                                             Noble Academy
# Job_title                                        Staff Pendidikan
# Location        Grogol Petamburan, Jakarta Barat, DKI Jakarta,...
# Salary                                                Rp5jt-Rp7jt
# Work Type                                             Penuh Waktu
# Skills          Lancar Berbahasa Inggris, Computer And Network...
# Descriptions                                                  NaN
# Links           https://glints.com/id/opportunities/jobs/staff...
# Name: 57, dtype: object
# Similarity 62: 0.4688253402709961, Job Title: Company                                           MITRAPABRIK.COM
# Job_title                                           Sales Counter
# Location                  Wiyung, Surabaya, Jawa Timur, Indonesia
# Salary                                              Rp2,5jt-Rp3jt
# Work Type                                             Penuh Waktu
# Skills          Memiliki Kemampuan Komunikasi Yang Baik, Mengu...
# Descriptions    Mengidentifikasi dan menghubungi prospek poten...
# Links           https://glints.com/id/opportunities/jobs/sales...
# Name: 24, dtype: object
